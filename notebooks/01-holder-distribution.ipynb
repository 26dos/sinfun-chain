# %% [markdown]
# # Top holder distribution by chain
#
# Compare top-1 holder concentration across solana, base, hyperliquid memecoins.

# %%
import pandas as pd
from sinfun.storage import read_all

df = read_all('data/')
df.groupby('chain')['top1_pct'].describe()
