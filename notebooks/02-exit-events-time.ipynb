# %% [markdown]
# # Exit-liquidity events over time
#
# When do exit-liq events cluster? Is there a day-of-week effect?

# %%
import pandas as pd
from sinfun.storage import read_all

df = read_all('data/', chain='solana')
df['day'] = pd.to_datetime(df['fetched_at']).dt.day_name()
df['day'].value_counts()
